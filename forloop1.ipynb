# %% [markdown]
# <a href="https://colab.research.google.com/github/Leroy-OP/PythonClass/blob/main/forloop1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,5):
    print(i**2)
# Out:
# 1
# 4
# 9
# 16

# %%
for i in range(10):
    if i==5:
        continue
    print(i)
total = 0
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
total=0
for i in range(0, 6):
    for j in range(0, 6):
        total = total + i + j
print("Sum is:", total)
# Out:
# Sum is: 180
